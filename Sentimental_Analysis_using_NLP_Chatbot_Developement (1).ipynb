# %%
from transformers import pipeline
import logging

# %%
from transformers import pipeline
sentiment_analyzer = pipeline("sentiment-analysis")
result = sentiment_analyzer("I love AI and coding!")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# ...

# %%
from transformers import pipeline
sentimental_analyzer = pipeline('sentiment-analysis')
result = sentiment_analyzer('i hate AI')
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'NEGATIVE', 'score': 0.9988223910331726}]

# %%
text = 'i love to work agentic models'
result = sentimental_analyzer (text)
print(result)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9986771941184998}]

# %%
label = result[0]['label']
score=result[0]['score']

print(f'label : {text}')
print(f"Sentiment: {label} (Confidence: {score:.0%})")
# Out:
# label : i love to work agentic models
# Sentiment: POSITIVE (Confidence: 100%)

# %%
chatbot = pipeline("text-generation", model="gpt2")
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
with open("/content/real_world_text.txt", "r"):
    text_data = file.read()
    print(text_data)
# Out:
# Weekly Sales Summary
# --------------------
# This week, the company achieved the following:
#
# - Laptops: 5 units sold, generating $5000 in revenue.
# - Smartphones: 10 units sold, generating $7000 in revenue.
# - Headphones: 15 units sold, generating $1500 in revenue.
# - Monitors: 3 units sold, generating $900 in revenue.
#
# Overall, total revenue for the week reached $14,400.
# The sales team performed exceptionally well, especially in the smartphone segment.
# Recommendations for next week:
# - Focus on marketing laptops and headphones.
# - Offer bundle deals to increase monitor sales.
# - Monitor stock levels closely to avoid shortages.

# %%
response = chatbot(text_data, max_length=100)
print(response[0]['generated_text'])
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# This week, the company achieved: - Laptops: 5 units sold, generating $5000 in revenue. - Smartphones: 10 units sold, generating $7000 in revenue. - Headphones: 15 units sold, generating $1500 in revenue. - Monitors: 3 units sold, generating $900 in revenue. Overall, total revenue for the week reached $14,400. The sales team performed exceptionally well, especially in the smartphone segment. Recommendations for next week: - Focus on marketing laptops and headphones. - Offer bundle deals to increase monitor sales. - Monitor stock levels closely to avoid shortages.

# %%
response = chatbot('Explain machine learning in summarize and give 1 real-life example explain both things')
print(response[0]['generated_text'])
# Out:
# Machine learning is a form of artificial intelligence.

# %%
response = chatbot('Classify this sentence as Positive or Negative:"I hate online classes"')
print(response[0]['generated_text'])
# Out:
# Negative

# %%
response = chatbot('Why does increasing model complexity reduce bias but increase variance? Explain reason?')
print(response[0]['generated_text'])
# Out:
# The more models that are used, the more complex the model will be.

# %%
chatbot = pipeline("text2text-generation",model="google/flan-t5-large")
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
user_input = text_data
print(user_input)
# Out:
# Weekly Sales Summary
# --------------------
# This week, the company achieved the following:
#
# - Laptops: 5 units sold, generating $5000 in revenue.
# - Smartphones: 10 units sold, generating $7000 in revenue.
# - Headphones: 15 units sold, generating $1500 in revenue.
# - Monitors: 3 units sold, generating $900 in revenue.
#
# Overall, total revenue for the week reached $14,400.
# The sales team performed exceptionally well, especially in the smartphone segment.
# Recommendations for next week:
# - Focus on marketing laptops and headphones.
# - Offer bundle deals to increase monitor sales.
# - Monitor stock levels closely to avoid shortages.

# %%
response = chatbot(user_input,max_length=100)
print(response[0]['generated_text'])
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# This week, the company achieved: - Laptops: 5 units sold, generating $5000 in revenue. - Smartphones: 10 units sold, generating $7000 in revenue. - Headphones: 15 units sold, generating $1500 in revenue. - Monitors: 3 units sold, generating $900 in revenue. Overall, total revenue for the week reached $14,400. The sales team performed exceptionally well, especially in the smartphone segment. Recommendations for next week: - Focus on marketing laptops and headphones. - Offer bundle deals to increase monitor sales. - Monitor stock levels closely to avoid shortages.

# %%
response = chatbot("Explain machine learning: summarize it and give 1 real-world example explain both things")
print(response[0]['generated_text'])
# Out:
# Machine learning is a type of artificial intelligence that learns from data. It can be applied to many fields, such as artificial intelligence in medicine, artificial intelligence in education, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in medicine, artificial intelligence in 
# ...

# %%
response = chatbot('Classify this sentence as Positive or Negative:"I hate online classes"')
print(response[0]['generated_text'])
# Out:
# Negative
